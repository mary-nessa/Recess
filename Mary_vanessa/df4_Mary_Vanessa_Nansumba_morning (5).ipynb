# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns=50
sns.set(style="darkgrid",rc ={"axes.facecolor":"#CAF1DE"})

# %%
df4 =pd.read_csv("/Users/mojca/Desktop/bse_dataset4.csv")
df4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
df4.shape
# Out:
# (169, 15)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 15 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           168 non-null    object
#  1   gender                                              169 non-null    object
#  2   Age                                                 167 non-null    float64
#  3   emotion                                             168 non-null    object
#  4   YOB                                                 169 non-null    object
#  5   CGPA                                                169 non-null    object
#  6   Do you have a Girl Friend or BOY Friend             169 non-null    object
#  7   Do you have Depression?                             169 non-null    object
# ...

# %%
df4_new=df4.dropna(inplace=True)
df4_new

# %%
df4['Calories'].fillna(100,inplace =True)
df4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
print(df4.to_string)
# Out:
# <bound method DataFrame.to_string of                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# Replace using Mean,Median,Mode
#Calculate Mean
m =df4['Calories'].mean()
df4['Calories'].fillna(m,inplace= True)
m
# Out:
# 371.91687500000006

# %%
print(df4.to_string)
# Out:
# <bound method DataFrame.to_string of                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
# Show  display all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_column', None)
df4
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# 13   05/07/2023 09:39:40           MALE  22.0                  fine
# ...

# %%
#Empty cells, Wrong Formats,Wrong data, duplicate(Core of data preparatio and preprocessing)
#Calculate MEDIAN
df4 =pd.read_csv("/Users/mojca/Desktop/bse_dataset4.csv")
md=df4['Calories'].median()
df4['Calories'].fillna(md,inplace=True)

# %%
df4
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5                    NaN         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
print(md)
# Out:
# 318.6

# %%
#EXERCISE1
#Calculate mode on Age
df4 =pd.read_csv("/Users/mojca/Desktop/bse_dataset4.csv")
mo=df4['Age'].mode()
df4['Age'].fillna(mo,inplace =True)
print(mo)
# Out:
# 0    21.0
# Name: Age, dtype: float64

# %%
df4
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5                    NaN         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
#Wrong Formats Rows that are hard to analyze(NaN,)
#2023112C
#NaN Row 5 contianed NaN values, and we filled with
#df4["Timestamp"].fillna("05/07/2023 09:45:13",inplace =True)
df4.at[10,"Timestamp"]="05/07/2023 09:45:13"
df4
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5    05/07/2023 09:45:13         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10   05/07/2023 09:45:13           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
#Wrong data 23,2300
#Row 23,37 contianed typo in data 23, 2300 typo , we changed from 2300 to 23
#Wrong data 2199, 21.99
df4 =pd.read_csv("/Users/mojca/Desktop/bse_dataset4.csv")
for x in df4.index:
    if df4.loc[x, "gender"] == "Marabou stock":
        df4.drop(x, inplace=True)

# %%
df4
# Out:
#                Timestamp   gender   Age               emotion            YOB  \
# 0    05/07/2023 09:38:39     Male  21.0               Content           2002
# 2    05/07/2023 09:39:09  Female   20.0                 Happy           2002
# 3    05/07/2023 09:39:12     Male  21.0                 Happy           2003
# 4    05/07/2023 09:39:14   Female  21.0                 Happy           2002
# 5                    NaN   Female  23.0                Happy            2000
# 6    05/07/2023 09:39:21   female  21.0            irritated            2001
# 7    05/07/2023 09:39:23  Female   22.0  In a state of wonder           2001
# 8    05/07/2023 09:39:26     Male  22.0                   Sad           2001
# 9    05/07/2023 09:39:27   Female  20.0                 happy           2002
# 10            2023/12/26     Male  24.0                 Happy           1998
# 11   05/07/2023 09:39:27   Female  20.0                 happy           2002
# ...

# %%
print(df4.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
# df4.drop_duplictes(inplace = True)
df4.drop_duplicates(inplace=True)

# %%
print(df4.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# ...

# %%
#Data Visualization, Plotting, matplot Library(Heatmap,piechart,lineplot(Dotted,,dashed))
#scatterplot library, histogram
import matplotlib.pyplot as plot

df4["Age"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Assignment
#using the first dataset  
import pandas as pd
df =pd.read_csv("/Users/mojca/Desktop/2018CrimeStatisticsByCategoryOfCrime(1).csv")
df
# Out:
#     Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0          NaN                    NaN            NaN                  NaN
# 1          NaN                    NaN   Totals Cases  Cases under Inquiry
# 2        S/No.  CASE/CRIME INCIDENCES              1                    2
# 3          NaN              HOMICIDES            NaN                  NaN
# 4            1   Death  (by shooting)            190                  117
# ..         ...                    ...            ...                  ...
# 122         98            UWA Statute            648                  112
# 123         99   Local Government Act              4                    2
# 124        100         All other Acts            821                  345
# 125        NaN  Sub Total(Other Laws)          3,006                  749
# 126        NaN            GRAND TOTAL        238,746               90,763
#
#            Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# ...

# %%
#determining number of columns and rows in the dataset
df.shape
# Out:
# (127, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   95 non-null     object
#  1   Unnamed: 1                   125 non-null    object
#  2   REPORTED CASES               125 non-null    object
#  3   Unnamed: 3                   125 non-null    object
#  4   Unnamed: 4                   125 non-null    object
#  5   Unnamed: 5                   125 non-null    object
#  6   PERFOMANCE                   125 non-null    object
#  7   Unnamed: 7                   125 non-null    object
#  8   Unnamed: 8                   125 non-null    object
#  9   Unnamed: 9                   125 non-null    object
#  10  Unnamed: 10                  125 non-null    object
#  11  PERSONS TAKEN TO COURT       126 non-null    object
#  12  Unnamed: 12                  124 non-null    object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#checking datatypes
df.dtypes
# Out:
# Unnamed: 0                     object
# Unnamed: 1                     object
# REPORTED CASES                 object
# Unnamed: 3                     object
# Unnamed: 4                     object
# Unnamed: 5                     object
# PERFOMANCE                     object
# Unnamed: 7                     object
# Unnamed: 8                     object
# Unnamed: 9                     object
# Unnamed: 10                    object
# PERSONS TAKEN TO COURT         object
# Unnamed: 12                    object
# Unnamed: 13                    object
# Unnamed: 14                    object
# Unnamed: 15                    object
# Unnamed: 16                    object
# Unnamed: 17                    object
# Unnamed: 18                    object
# Unnamed: 19                    object
# Unnamed: 20                    object
# Unnamed: 21                    object
# SENTENCES IMPOSED BY COURTS    object
# Unnamed: 23                    object
# Unnamed: 24                    object
# ...

# %%
#using fillna() to fill all empty cells in the dataset with 0
df=df.fillna(value=0)
df
# Out:
#     Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0            0                      0              0                    0
# 1            0                      0   Totals Cases  Cases under Inquiry
# 2        S/No.  CASE/CRIME INCIDENCES              1                    2
# 3            0              HOMICIDES              0                    0
# 4            1   Death  (by shooting)            190                  117
# ..         ...                    ...            ...                  ...
# 122         98            UWA Statute            648                  112
# 123         99   Local Government Act              4                    2
# 124        100         All other Acts            821                  345
# 125          0  Sub Total(Other Laws)          3,006                  749
# 126          0            GRAND TOTAL        238,746               90,763
#
#            Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# ...

# %%
df1.isnull().sum().sort_values(ascending=False)
# Out:
# SCHOOL                1
# YEAR                  0
# MALE TOTAL DIV2       0
# FEMALE TOTAL DIV7     0
# FEMALE % DIV7         0
# FEMALE TOTAL DIV9     0
# FEMALE % DIV9         0
# FEMALE TOTAL X        0
# FEMALE % X            0
# MALE CANDIDATES       0
# MALE TOTAL DIV1       0
# MALE % DIV1           0
# MALE % DIV2           0
# FEMALE TOTAL DIV4     0
# MALE TOTAL DIV3       0
# MALE % DIV3           0
# MALE TOTAL DIV4       0
# MALE % DIV4           0
# MALE TOTAL DIV7       0
# MALE % DIV7           0
# MALE TOTAL DIV9       0
# MALE % DIV9           0
# MALE TOTAL X          0
# FEMALE % DIV4         0
# FEMALE % DIV3         0
# DISTRICT              0
# TOTAL DIV 7           0
# TOTAL CANDIDATES      0
# TOTAL DIV 1           0
# % DIV 1               0
# TOTAL DIV 2           0
# % DIV 2               0
# TOTAL DIV 3           0
# % DIV 3               0
# TOTAL DIV 4           0
# % DIV 4               0
# % DIV 7               0
# FEMALE TOTAL DIV3     0
# ...

# %%
#checking datatypes
df1.dtypes
# Out:
# YEAR                    int64
# DISTRICT               object
# SCHOOL                 object
# TOTAL CANDIDATES      float64
# TOTAL DIV 1           float64
# % DIV 1               float64
# TOTAL DIV 2           float64
# % DIV 2               float64
# TOTAL DIV 3           float64
# % DIV 3               float64
# TOTAL DIV 4           float64
# % DIV 4               float64
# TOTAL DIV 7           float64
# % DIV 7               float64
# TOTAL DIV 9           float64
# % DIV 9               float64
# TOTAL X               float64
# % X                   float64
# FEMALE CANDIDATES       int64
# FEMALE TOTAL DIV1     float64
# FEMALE % DIV1         float64
# FEMALE TOTAL DIV2     float64
# FEMALE % DIV2         float64
# FEMALE TOTAL DIV3     float64
# FEMALE % DIV3         float64
# FEMALE TOTAL DIV4     float64
# FEMALE % DIV4         float64
# FEMALE TOTAL DIV7     float64
# FEMALE % DIV7         float64
# FEMALE TOTAL DIV9     float64
# FEMALE % DIV9         float64
# ...

# %%
# Get a list of unnamed columns
unnamed_columns = [col for col in df1.columns if 'Unnamed' in col]

# Create a mapping dictionary for new column names
column_mapping = {}
i=0
for col in unnamed_columns:
    i+=1
    # Replace 'Unnamed' with a meaningful name of your choice
    new_name = col.replace('Unnamed', 'Cl{}'.format(i))
    column_mapping[col] = new_name
    

# Rename the unnamed columns
df1.rename(columns=column_mapping, inplace=True)

# Verify the changes
df1.columns
# Out:
# Index(['YEAR', 'DISTRICT ', 'SCHOOL', 'TOTAL CANDIDATES', 'TOTAL DIV 1',
#        '% DIV 1', 'TOTAL DIV 2', '% DIV 2', 'TOTAL DIV 3', '% DIV 3',
#        'TOTAL DIV 4', '% DIV 4', 'TOTAL DIV 7', '% DIV 7', 'TOTAL DIV 9',
#        '% DIV 9', 'TOTAL X', '% X', 'FEMALE CANDIDATES', 'FEMALE TOTAL DIV1 ',
#        'FEMALE % DIV1 ', 'FEMALE TOTAL DIV2 ', 'FEMALE % DIV2',
#        'FEMALE TOTAL DIV3', 'FEMALE % DIV3', 'FEMALE TOTAL DIV4',
#        'FEMALE % DIV4', 'FEMALE TOTAL DIV7', 'FEMALE % DIV7',
#        'FEMALE TOTAL DIV9', 'FEMALE % DIV9', 'FEMALE TOTAL X', 'FEMALE % X ',
#        'MALE CANDIDATES', 'MALE TOTAL DIV1 ', 'MALE % DIV1 ',
#        'MALE TOTAL DIV2 ', 'MALE % DIV2', 'MALE TOTAL DIV3', 'MALE % DIV3',
#        'MALE TOTAL DIV4', 'MALE % DIV4 ', 'MALE TOTAL DIV7 ', 'MALE % DIV7',
#        'MALE TOTAL DIV9 ', 'MALE % DIV9', 'MALE TOTAL X ', 'MALE % X'],
#       dtype='object')

# %%
# Count the number of NaN values in each column
nan_counts = df1.isnull().sum()
print("Number of NaN values in each column:\n", nan_counts)
# Out:
# Number of NaN values in each column:
#  YEAR                  0
# DISTRICT              0
# SCHOOL                1
# TOTAL CANDIDATES      0
# TOTAL DIV 1           0
# % DIV 1               0
# TOTAL DIV 2           0
# % DIV 2               0
# TOTAL DIV 3           0
# % DIV 3               0
# TOTAL DIV 4           0
# % DIV 4               0
# TOTAL DIV 7           0
# % DIV 7               0
# TOTAL DIV 9           0
# % DIV 9               0
# TOTAL X               0
# % X                   0
# FEMALE CANDIDATES     0
# FEMALE TOTAL DIV1     0
# FEMALE % DIV1         0
# FEMALE TOTAL DIV2     0
# FEMALE % DIV2         0
# FEMALE TOTAL DIV3     0
# FEMALE % DIV3         0
# FEMALE TOTAL DIV4     0
# FEMALE % DIV4         0
# FEMALE TOTAL DIV7     0
# FEMALE % DIV7         0
# FEMALE TOTAL DIV9     0
# FEMALE % DIV9         0
# FEMALE TOTAL X        0
# FEMALE % X            0
# MALE CANDIDATES       0
# MALE TOTAL DIV1       0
# MALE % DIV1           0
# ...

# %%
#import pandas as pd
#reading the dataset
import pandas as pd
df1=pd.read_csv("/Users/mojca/Desktop/Mary-Nansumba/UceResultsBySchool2011-2016 (1).csv")
df1
# Out:
#        YEAR      DISTRICT                                              SCHOOL  \
# 0      2011         WAKISO                                 GAYAZA HIGH SCHOOL
# 1      2011         MUKONO                                 NAMILYANGO COLLEGE
# 2      2011         MUKONO                             MT.ST.MARY'S,NAMAGUNGA
# 3      2011         WAKISO                        UGANDA MARTYRS SS,NAMUGONGO
# 4      2011  BUSHENYI MAIN                                    KITABI SEMINARY
# ...     ...            ...                                                ...
# 17634  2016          ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016          ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016          ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016          ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016          ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
# ...

# %%
#determining number of columns and rows in the dataset
df1.shape
# Out:
# (17639, 48)

# %%
#determining the columns in the dataset
df1.columns
# Out:
# Index(['YEAR', 'DISTRICT ', 'SCHOOL', 'TOTAL CANDIDATES', 'TOTAL DIV 1',
#        '% DIV 1', 'TOTAL DIV 2', '% DIV 2', 'TOTAL DIV 3', '% DIV 3',
#        'TOTAL DIV 4', '% DIV 4', 'TOTAL DIV 7', '% DIV 7', 'TOTAL DIV 9',
#        '% DIV 9', 'TOTAL X', '% X', 'FEMALE CANDIDATES', 'FEMALE TOTAL DIV1 ',
#        'FEMALE % DIV1 ', 'FEMALE TOTAL DIV2 ', 'FEMALE % DIV2',
#        'FEMALE TOTAL DIV3', 'FEMALE % DIV3', 'FEMALE TOTAL DIV4',
#        'FEMALE % DIV4', 'FEMALE TOTAL DIV7', 'FEMALE % DIV7',
#        'FEMALE TOTAL DIV9', 'FEMALE % DIV9', 'FEMALE TOTAL X', 'FEMALE % X ',
#        'MALE CANDIDATES', 'MALE TOTAL DIV1 ', 'MALE % DIV1 ',
#        'MALE TOTAL DIV2 ', 'MALE % DIV2', 'MALE TOTAL DIV3', 'MALE % DIV3',
#        'MALE TOTAL DIV4', 'MALE % DIV4 ', 'MALE TOTAL DIV7 ', 'MALE % DIV7',
#        'MALE TOTAL DIV9 ', 'MALE % DIV9', 'MALE TOTAL X ', 'MALE % X'],
#       dtype='object')

# %%
#summing up null values(cells) in each column
df1.isnull().sum().sort_values(ascending=False)
# Out:
# FEMALE TOTAL DIV7     12875
# TOTAL DIV 7           11150
# MALE TOTAL DIV7       10131
# FEMALE TOTAL DIV1      9114
# MALE TOTAL DIV1        7601
# MALE TOTAL X           7260
# MALE TOTAL DIV9        7120
# FEMALE TOTAL X         7043
# FEMALE TOTAL DIV9      5290
# TOTAL DIV 1            4781
# TOTAL X                4235
# TOTAL DIV 9            4185
# FEMALE TOTAL DIV2      3307
# MALE TOTAL DIV2        2397
# MALE TOTAL DIV4        1379
# MALE TOTAL DIV3        1240
# FEMALE TOTAL DIV3      1165
# FEMALE TOTAL DIV4       958
# TOTAL DIV 2             759
# TOTAL DIV 4             751
# TOTAL DIV 3             471
# TOTAL CANDIDATES        271
# MALE % DIV4             134
# MALE % DIV3             134
# MALE % DIV7             134
# MALE % DIV2             134
# MALE % DIV1             134
# MALE % DIV9             134
# MALE % X                134
# FEMALE % X               58
# FEMALE % DIV3            58
# FEMALE % DIV9            58
# FEMALE % DIV4            58
# ...

# %%
#summing up the duplicates rows/ duplicates
pd.set_option('display.max_rows', None)
print(df1.duplicated())
df1.duplicated().sum()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
# 30       False
# 31       False
# 32       False
# 33       False
# 34       False
# 35       False
# 36       False
# 37       False
# 38       False
# 39       False
# 40       False
# 41       False
# 42       False
# 43       False
# 44       False
# 45       False
# 46       False
# 47       False
# 48       False
# 49       False
# 50       False
# 51       False
# 52       False
# 53       False
# 54       False
# 55       False
# 56       False
# 57       False
# ...

# %%
df1_new =df1.dropna()
df1_new
# Out:
#        YEAR  DISTRICT                                              SCHOOL  \
# 3197   2012      JINJA                             JINJA SECONDARY SCHOOL
# 3263   2012     WAKISO                       VICTORIA HIGH SCHOOL,NANSANA
# 3327   2012    KAMPALA                               MBUYA COLLEGE SCHOOL
# 3444   2012    KAMPALA                            KOLOLO SECONDARY SCHOOL
# 3549   2012  RUKUNGIRI                              RUKUNGIRI HIGH SCHOOL
# ...     ...        ...                                                ...
# 17634  2016      ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016      ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016      ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016      ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016      ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
#        TOTAL CANDIDATES  TOTAL DIV 1  % DIV 1  TOTAL DIV 2  % DIV 2  \
# ...

# %%
# Check for NaN values in the entire DataFrame
nan_values = df1.isnull().values.any()
print("NaN values in the dataset", nan_values)
# Out:
# NaN values in the dataset True

# %%
# Count the number of NaN values in each column
nan_counts = df1.isnull().sum()
print("Number of NaN values in each column:\n", nan_counts)
# Out:
# Number of NaN values in each column:
#  YEAR                      0
# DISTRICT                  0
# SCHOOL                    1
# TOTAL CANDIDATES        271
# TOTAL DIV 1            4781
# % DIV 1                   0
# TOTAL DIV 2             759
# % DIV 2                   0
# TOTAL DIV 3             471
# % DIV 3                   0
# TOTAL DIV 4             751
# % DIV 4                   0
# TOTAL DIV 7           11150
# % DIV 7                   0
# TOTAL DIV 9            4185
# % DIV 9                   0
# TOTAL X                4235
# % X                       0
# FEMALE CANDIDATES         0
# FEMALE TOTAL DIV1      9114
# FEMALE % DIV1            58
# FEMALE TOTAL DIV2      3307
# FEMALE % DIV2            58
# FEMALE TOTAL DIV3      1165
# FEMALE % DIV3            58
# FEMALE TOTAL DIV4       958
# FEMALE % DIV4            58
# FEMALE TOTAL DIV7     12875
# FEMALE % DIV7            58
# FEMALE TOTAL DIV9      5290
# FEMALE % DIV9            58
# FEMALE TOTAL X         7043
# ...

# %%
off = ['YEAR', 'DISTRICT ', 'SCHOOL', 'TOTAL CANDIDATES']
for col in df1.columns:
    if col not in off:
        if np.issubdtype(df1[col].dtype, np.number):
            df1[col].plot(kind='pie')
            plt.title(col)
            plt.show()

# %%
import numpy as np
# Identify numeric columns with NaN values
numeric_columns_with_nan = []
for column in df1.columns:
    if np.issubdtype(df1[column].dtype, np.number) and df1[column].isnull().values.any():
        numeric_columns_with_nan.append(column)

# Calculate median for each numeric column and fill NaN values
for column in numeric_columns_with_nan:
    column_median = df1[column].median()
    df1[column].fillna(column_median, inplace=True)

# Verify if NaN values have been filled
nan_values_remaining = df1.isnull().sum().sum()
print("Number of NaN values remaining:", nan_values_remaining)

# %%
#Reading the third dataset
import pandas as pd

dm = pd.read_csv("/Users/mojca/Desktop/Mary-Nansumba/MPsProfileInformation10thParliament (1).csv", encoding='latin-1')
dm
# Out:
#      No.                              Name of M.P              District  \
# 0      1                       Aadroa Alex Onzima                   NaN
# 1      2                            Ababiku Jesca              Adjumani
# 2      3          ABACANON CHARLES ANGIRO GUTOMOI                  Lira
# 3      4                              ABALA DAVID                 Ngora
# 4      5                     ABBAS AGABA MUGISHA               Kamwenge
# 5      6                 ABIGABA CUTHBERT MIREMBE              Kamwenge
# 6      7            Abiriga Ibrahim Yusuf Abdalla                  Arua
# 7      8                        Abott Goerge Ouma             NAMAYINGO
# 8      9                          Aceng Jane Ruth                   NaN
# 9     10                       Acen Christine Ayo              Alebtong
# 10    11                            Achia Remigio         Nakapiripirit
# 11    12                       Achia Terence Naco                 Napak
# ...

# %%
dm.columns
# Out:
# Index(['YEAR', 'DISTRICT ', 'SCHOOL', 'TOTAL CANDIDATES', 'TOTAL DIV 1',
#        '% DIV 1', 'TOTAL DIV 2', '% DIV 2', 'TOTAL DIV 3', '% DIV 3',
#        'TOTAL DIV 4', '% DIV 4', 'TOTAL DIV 7', '% DIV 7', 'TOTAL DIV 9',
#        '% DIV 9', 'TOTAL X', '% X', 'FEMALE CANDIDATES', 'FEMALE TOTAL DIV1 ',
#        'FEMALE % DIV1 ', 'FEMALE TOTAL DIV2 ', 'FEMALE % DIV2',
#        'FEMALE TOTAL DIV3', 'FEMALE % DIV3', 'FEMALE TOTAL DIV4',
#        'FEMALE % DIV4', 'FEMALE TOTAL DIV7', 'FEMALE % DIV7',
#        'FEMALE TOTAL DIV9', 'FEMALE % DIV9', 'FEMALE TOTAL X', 'FEMALE % X ',
#        'MALE CANDIDATES', 'MALE TOTAL DIV1 ', 'MALE % DIV1 ',
#        'MALE TOTAL DIV2 ', 'MALE % DIV2', 'MALE TOTAL DIV3', 'MALE % DIV3',
#        'MALE TOTAL DIV4', 'MALE % DIV4 ', 'MALE TOTAL DIV7 ', 'MALE % DIV7',
#        'MALE TOTAL DIV9 ', 'MALE % DIV9', 'MALE TOTAL X ', 'MALE % X'],
#       dtype='object')

# %%
dm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17639 entries, 0 to 17638
# Data columns (total 48 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   YEAR                17639 non-null  int64
#  1   DISTRICT            17639 non-null  object
#  2   SCHOOL              17638 non-null  object
#  3   TOTAL CANDIDATES    17639 non-null  float64
#  4   TOTAL DIV 1         17639 non-null  float64
#  5   % DIV 1             17639 non-null  float64
#  6   TOTAL DIV 2         17639 non-null  float64
#  7   % DIV 2             17639 non-null  float64
#  8   TOTAL DIV 3         17639 non-null  float64
#  9   % DIV 3             17639 non-null  float64
#  10  TOTAL DIV 4         17639 non-null  float64
#  11  % DIV 4             17639 non-null  float64
#  12  TOTAL DIV 7         17639 non-null  float64
#  13  % DIV 7             17639 non-null  float64
#  14  TOTAL DIV 9         17639 non-null  float64
# ...

# %%
dm.isnull().sum().sort_values(ascending=False)
# Out:
# SCHOOL                1
# YEAR                  0
# MALE TOTAL DIV2       0
# FEMALE TOTAL DIV7     0
# FEMALE % DIV7         0
# FEMALE TOTAL DIV9     0
# FEMALE % DIV9         0
# FEMALE TOTAL X        0
# FEMALE % X            0
# MALE CANDIDATES       0
# MALE TOTAL DIV1       0
# MALE % DIV1           0
# MALE % DIV2           0
# FEMALE TOTAL DIV4     0
# MALE TOTAL DIV3       0
# MALE % DIV3           0
# MALE TOTAL DIV4       0
# MALE % DIV4           0
# MALE TOTAL DIV7       0
# MALE % DIV7           0
# MALE TOTAL DIV9       0
# MALE % DIV9           0
# MALE TOTAL X          0
# FEMALE % DIV4         0
# FEMALE % DIV3         0
# DISTRICT              0
# TOTAL DIV 7           0
# TOTAL CANDIDATES      0
# TOTAL DIV 1           0
# % DIV 1               0
# TOTAL DIV 2           0
# % DIV 2               0
# TOTAL DIV 3           0
# % DIV 3               0
# TOTAL DIV 4           0
# % DIV 4               0
# % DIV 7               0
# FEMALE TOTAL DIV3     0
# ...
